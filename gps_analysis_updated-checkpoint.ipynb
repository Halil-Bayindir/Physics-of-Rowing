# %%
# %matplotlib inline

# %% [markdown]
# # GPS data w/ python, Florian Wilhelm
#
# https://github.com/FlorianWilhelm/gps_data_with_python/tree/master
#
# https://youtu.be/jAKUPm-Cul0

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
import gpxpy
import gpxpy.gpx

from gps_utils import rdp

# Parsing an existing file:
# -------------------------

gpx_file = open('./data/activity_10578864150.gpx', 'r')
#gpx_file = open('./data/activity_11723677324.gpx', 'r')

gpx = gpxpy.parse(gpx_file)

# %%
# !gpxinfo './data/activity_10578864150.gpx'
#!gpxinfo './data/activity_11723677324.gpx'
# Out:
# File: ./data/activity_10578864150.gpx
#     Length 2D: 6.262km
#     Length 3D: 6.262km
#     Moving time: 00:47:16
#     Stopped time: 00:00:42
#     Max speed: 2.75m/s = 9.90km/h (raw: 3.20m/s = 11.52km/h)
#     Avg speed: 2.20m/s = 7.94km/h
#     Total uphill: 0.00m
#     Total downhill: 0.00m
#     Started: 2023-02-25 05:11:11+00:00
#     Ended: 2023-02-25 05:59:09+00:00
#     Points: 794
#     Avg distance between points: 7.89m
#
#     Track #0, Segment #0
#         Length 2D: 6.262km
#         Length 3D: 6.262km
#         Moving time: 00:47:16
#         Stopped time: 00:00:42
#         Max speed: 2.75m/s = 9.90km/h (raw: 3.20m/s = 11.52km/h)
#         Avg speed: 2.20m/s = 7.94km/h
#         Total uphill: 0.00m
#         Total downhill: 0.00m
#         Started: 2023-02-25 05:11:11+00:00
#         Ended: 2023-02-25 05:59:09+00:00
#         Points: 794
#         Avg distance between points: 7.89m

# %%
moving_data = gpx.get_moving_data(raw=True)

# %%
moving_data
# Out:
# MovingData(moving_time=2836.0, stopped_time=42.0, moving_distance=6253.202901503913, stopped_distance=8.387952547166085, max_speed=3.19984486209668)

# %%
segment = gpx.tracks[0].segments[0]

# %%
coords = pd.DataFrame([
        {'lat'  : p.latitude, 
         'lon'  : p.longitude, 
         'ele'  : p.elevation,
         'time' : p.time,
         'speed': p.speed } for p in segment.points])
coords.set_index('time', drop=True, inplace=True)
coords.head(20)
# Out:
#                                  lat        lon   ele speed
# time
# 2023-02-25 05:11:11+00:00  40.738518  30.285841  None  None
# 2023-02-25 05:11:12+00:00  40.738518  30.285840  None  None
# 2023-02-25 05:11:23+00:00  40.738504  30.285815  None  None
# 2023-02-25 05:11:25+00:00  40.738505  30.285807  None  None
# 2023-02-25 05:11:29+00:00  40.738506  30.285777  None  None
# 2023-02-25 05:11:37+00:00  40.738512  30.285686  None  None
# 2023-02-25 05:11:38+00:00  40.738514  30.285669  None  None
# 2023-02-25 05:11:51+00:00  40.738514  30.285486  None  None
# 2023-02-25 05:11:56+00:00  40.738508  30.285419  None  None
# 2023-02-25 05:11:58+00:00  40.738502  30.285395  None  None
# 2023-02-25 05:12:01+00:00  40.738488  30.285350  None  None
# 2023-02-25 05:12:10+00:00  40.738474  30.285222  None  None
# 2023-02-25 05:12:21+00:00  40.738441  30.285057  None  None
# 2023-02-25 05:12:26+00:00  40.738409  30.284970  None  None
# 2023-02-25 05:12:30+00:00  40.738390  30.284906  None  None
# 2023-02-25 05:12:35+00:00  40.738365  30.284824  None  None
# 2023-02-25 05:12:39+00:00  40.738347  30.284759  None  None
# 2023-02-25 05:12:41+00:00  40.738334  30.284724  None  None
# 2023-02-25 05:12:43+00:00  40.738320  30.284690  None  None
# 2023-02-25 05:12:46+00:00  40.738304  30.284643  None  None

# %%
tdelta = np.diff(coords.index)

# %%
plt.figure(figsize=(10,6))
plt.plot( tdelta.astype('timedelta64[s]'), '.')
plt.xlabel('data point')
plt.ylabel('Delta t (s)');

# %%
coords['lat']
# Out:
# time
# 2023-02-25 05:11:11+00:00    40.738518
# 2023-02-25 05:11:12+00:00    40.738518
# 2023-02-25 05:11:23+00:00    40.738504
# 2023-02-25 05:11:25+00:00    40.738505
# 2023-02-25 05:11:29+00:00    40.738506
#                                ...
# 2023-02-25 05:58:58+00:00    40.738463
# 2023-02-25 05:59:00+00:00    40.738460
# 2023-02-25 05:59:03+00:00    40.738465
# 2023-02-25 05:59:06+00:00    40.738464
# 2023-02-25 05:59:09+00:00    40.738464
# Name: lat, Length: 794, dtype: float64

# %%
nskip=10
#plt.plot(coords['lon'].values, coords['lat'].values)
plt.plot(coords['lon'].values[::nskip], coords['lat'].values[::nskip], 'ro');

# %% [markdown]
# # Plot with mplleaflet

# %%
# prepare 3-laender-giro gps track
simple_coords = rdp(coords[['lon', 'lat']].values, epsilon=1e-5)

# %%
len(simple_coords)
# Out:
# 104

# %%
fig = plt.figure()
plt.plot(simple_coords[:, 0], simple_coords[:, 1])
plt.plot(simple_coords[:, 0], simple_coords[:, 1], 'r.');

# %% [markdown]
# # Speed

# %%
segment.points[0].speed, segment.points[-1].speed = 0., 0.
gpx.add_missing_speeds()
speed = np.array([p.speed for p in segment.points])
plt.plot(speed);

# %%
coords['speed'] = speed

# %%
upsampled = coords.resample('500L').ffill()

# %%
upsampled['speed'].plot()

# %% [markdown]
# # Acceleration

# %%
acceleration = np.gradient(upsampled['speed'])
plt.figure(figsize=(30,15))
plt.plot(acceleration, '.-')
cut=[410,610]
plt.axvline(cut[0],ls='--',color='k')
plt.axvline(cut[1],ls='--',color='k');
plt.axhline(0,ls='--',color='r');

# %%
data = acceleration[cut[0]:cut[1]]
len(data)
# Out:
# 200

# %%
plt.plot(data,'.-');

# %%
mean = np.average(data)
mean
# Out:
# 0.0027171921521361633

# %%
norm_data = data-mean

# %%
data_fft = np.fft.fft(data)

# %%
Nt=len(data)

# %%
freqs = np.fft.fftfreq(Nt)

# %%
plt.plot(np.roll(freqs,Nt//2),np.roll(data_fft,Nt//2),'.-');
# Out:
# /home/subasi/miniconda3/envs/juplab/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
corr =  np.correlate(norm_data,norm_data,mode='full')

# %%
plt.plot(corr[corr.size//2:corr.size//2+60],'.')

# %% [markdown]
# # Resistance

# %%
# if we assume that constants are equal to one
rho = 1 # rho = density
Cd = 1 # Cd = drag coefficient
Area = 1
Fdrag = 1/2*rho*Cd*Area*speed**2
plt.plot(Fdrag)

# %% [markdown]
# # Power

# %%
power = Fdrag*speed
plt.plot(power)
